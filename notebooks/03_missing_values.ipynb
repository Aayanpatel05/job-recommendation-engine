# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")
jobs = read.csv("../tech_jobs_clean.csv")

# %%
skills = {
    "Python", "Java", "C++", "SQL", "Machine Learning", "Data Analysis", "Communication", "Problem Solving",
    "Deep Learning", "Natural Language Processing", "Numpy", "Pandas", "Scikit-learn", "TensorFlow", "Keras",
    "PyTorch", "R", "SAS", "Tableau"
}

# %%
def extract_skills(text):
    doc = nlp(text)
    extracted_skills = set()
    for token in doc:
        if token.text in skills:
            extracted_skills.add(token.text)
    return extracted_skills

# %%
jobs['extracted_skills'] = jobs['description'].apply(extract_skills)
